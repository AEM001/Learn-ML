# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn

data=np.loadtxt('apple_prices.csv',dtype=float)
data=torch.from_numpy(data)

num=len(data)
split=int(0.8*num)
train_data=data[:split]
test_data=data[split:]

x=np.arange(num)
x
plt.figure(figsize=(10,6))
plt.plot(x, data, label='price_data')

plt.show()
